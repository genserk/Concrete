# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
concrete = pd.read_csv('data/concrete.csv')
concrete_train, concrete_test = train_test_split(concrete,
                                                 shuffle=True,
                                                 random_state=487)

features = concrete.columns[:-3]

# %%
sns.pairplot(concrete,x_vars=['cement','superplastic','water'],y_vars=['age'])
plt.show()

# %%
concrete.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %%
fig, ax = plt.subplots(2,4)
ax[0][0].hist(concrete['cement'])
ax[0][0].set_title('cement',fontsize='xx-large')
ax[0][1].hist(concrete['slag'])
ax[0][1].set_title('slag',fontsize='xx-large')
ax[0][2].hist(concrete['ash'])
ax[0][2].set_title('ash',fontsize='xx-large')
ax[0][3].hist(concrete['water'])
ax[0][3].set_title('water',fontsize='xx-large')
ax[1][0].hist(concrete['superplastic'])
ax[1][0].set_title('superplastic',fontsize='xx-large')
ax[1][1].hist(concrete['coarseagg'])
ax[1][1].set_title('coarseagg',fontsize='xx-large')
ax[1][2].hist(concrete['fineagg'])
ax[1][2].set_title('fineagg',fontsize='xx-large')
ax[1][3].hist(concrete['age'])
ax[1][3].set_title('age',fontsize='xx-large')
fig.set_size_inches((12,7))
plt.show()
